# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mpl_dates
from datetime import datetime, timedelta

# %%
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)

# %%
plt.style.use('seaborn')

dates =[
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0,1,3,4,6,5,7]

plt.plot_date(dates, y)


plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

dates =[
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0,1,3,4,6,5,7]

plt.plot_date(dates, y, linestyle='solid')


plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

dates =[
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0,1,3,4,6,5,7]

plt.plot_date(dates, y, linestyle='solid')

plt.gcf().autofmt_xdate() #get current figure dot, auto format x_date


plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

dates =[
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0,1,3,4,6,5,7]

plt.plot_date(dates, y, linestyle='solid')

plt.gcf().autofmt_xdate()

date_format = mpl_dates.DateFormatter('%b, %d, %Y') # Name of month %b, day %d, year %Y

plt.gca().xaxis.set_major_formatter(date_format) #get current axis, and set date_format


plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

data = pd.read_csv("data4.csv")

price_date = data['Date']
price_close = data['Close']

plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate()


plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

data = pd.read_csv("data5.csv") #This puts another May 18th in data5.csv
# This is because it is being read in as a string, not a date

price_date = data['Date']
price_close = data['Close']

plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate()


plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

data = pd.read_csv("data6.csv") #This put May 17th in data6.csv at the end
# This is because it is being read in as a string, not a date

price_date = data['Date']
price_close = data['Close']

plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate()


plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

data = pd.read_csv("data6.csv")

data['Date'] = pd.to_datetime(data['Date']) # This converts the string 'Date' to a real date
data.sort_values('Date', inplace=True) # This sorts the date in the same variable

price_date = data['Date']
price_close = data['Close']

plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate()


plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()

plt.show()
